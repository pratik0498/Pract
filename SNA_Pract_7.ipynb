# %%
"""
SNA Pratical 7 : Create sociograms for
1.the persons-by-persons network and
2.the committee-bycommittee network for a given relevant problem
3.create one-mode network and two-node network for the same
"""
# Out:
# '\nSNA Pratical 7 : Create sociograms for\n1.the persons-by-persons network and\n2.the committee-bycommittee network for a given relevant problem\n3.create one-mode network and two-node network for the same\n'

# %%
pip install networkx
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
persons = ['Person1','Person2','Person3','Person4' ]
committees = ['CommitteeA','CommitteeB','CommitteeC','CommitteeD', ]
G = nx.Graph()
G.add_nodes_from(persons, bipartite=0)
G.add_nodes_from(committees, bipartite=1)



G.add_edges_from([
    ('Person1', 'CommitteeA') , ('Person2', 'CommitteeB') ,('Person3', 'CommitteeC') ,('Person4', 'CommitteeD') ,('Person3', 'CommitteeC')  
])
pos = nx.bipartite_layout(G, persons)
nx.draw(G,pos,with_labels=True , font_weight='bold', node_color='pink', font_color='black', node_size = 800)
plt.title("Persons-by-Committees bipartite Graph")
plt.show()

# %%
persons_graph = nx.bipartite.projected_graph(G,persons)

pos_persons = nx.spring_layout(persons_graph)

nx.draw(persons_graph, pos_persons, with_labels=True, font_weight='bold', node_color='skyblue', font_color='black', node_size=800)
plt.title("Persons-by-Persons Network")
# Out:
# Text(0.5, 1.0, 'Persons-by-Persons Network')

# %%
committees_graph = nx.bipartite.projected_graph(G,committees)
pos_committees = nx.spring_layout(committees_graph)

nx.draw(committees_graph, pos_committees ,with_labels=True , font_weight='bold', node_color='skyblue', font_color='black', node_size = 800)
plt.title("Committees-by-Committees Network")
plt.show()
